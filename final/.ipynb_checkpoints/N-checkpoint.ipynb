# %%
import os
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, roc_auc_score, recall_score, precision_score, confusion_matrix

# %%
colors = sns.color_palette("tab10")
colors
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %% [markdown]
# # Rename image

# %%
data = []
counter = 0
for name_pref in ['accordeon', 'dombyra', 'kobyz']:
    i = 0
    for root, dirs, files in os.walk("data/" + name_pref, topdown=False):
        for name in files:
            try:
                img = cv2.imread(f'{root}\\{name}')
                data.append((counter, name_pref, name, img.shape[0], img.shape[1], img.ravel().mean(), img[:,:,0].mean(), img[:,:,1].mean(), img[:,:,2].mean()))
                i+=1
                counter+=1
            except:
                print(name)
# Out:
# accordeon0222.jpg
# accordeon0223.jpg

# %% [markdown]
# # Exploratory data analysis

# %%
image_data = pd.DataFrame(data=data, columns=['id', 'y', 'label', 'width', 'height', 
                                 'total_intense', 'red_intense', 'green_intense', 'blue_intense']).set_index('id')

# %%
image_data.head()
# Out:
#             y              label  width  height  total_intense  red_intense  \
# id
# 0   accordeon  accordeon0000.jpg   1500    1500     195.946269   186.722435
# 1   accordeon  accordeon0001.jpg    480     660     142.698965   137.292778
# 2   accordeon  accordeon0002.jpg    450     760     160.922645   160.072363
# 3   accordeon  accordeon0003.jpg    450     760     139.444899   134.803643
# 4   accordeon  accordeon0004.jpg    450     760     150.248596   142.968596
#
#     green_intense  blue_intense
# id
# 0      184.149238    216.967135
# 1      137.349066    153.455051
# 2      160.140854    162.554719
# 3      145.584456    137.946596
# 4      149.710705    158.066488

# %%
image_data.describe()
# Out:
#              width       height  total_intense  red_intense  green_intense  \
# count   616.000000   616.000000     616.000000   616.000000     616.000000
# mean    380.194805   405.400974     152.245348   145.645328     150.957762
# std     474.517241   458.221773      50.872773    52.669776      51.715261
# min     100.000000   100.000000      12.937457     9.012630      13.370006
# 25%     186.750000   194.000000     115.301189   105.949958     113.213844
# 50%     225.000000   259.000000     148.609597   141.288668     146.821682
# 75%     357.750000   351.500000     193.140418   187.610827     190.626775
# max    4608.000000  4472.000000     250.977433   249.300396     251.396207
#
#        blue_intense
# count    616.000000
# mean     160.132953
# std       51.579499
# min       16.429733
# 25%      121.574681
# 50%      158.885257
# 75%      204.537965
# max      252.235697

# %%
image_data.shape
# Out:
# (616, 8)

# %%
image_data.groupby('y')[['total_intense', 'red_intense', 
                         'green_intense', 'blue_intense']].mean().plot(figsize=(15, 10), 
                        kind='bar', legend=['Total intense', 'Red intense', 'Green intense', 'Blue intense'],
                        color = ['gray', colors[0], colors[2], colors[5]]);

# %%
plt.figure(figsize=(15,10))
plt.hist(image_data[image_data['y']=='accordeon']['total_intense'], color = colors[0])
plt.hist(image_data[image_data['y']=='dombyra']['total_intense'], color = colors[2], alpha = 0.5)
plt.hist(image_data[image_data['y']=='kobyz']['total_intense'], color = colors[5], alpha = 0.5)
plt.title(f'Image width distribution')
plt.xlabel('Width size')
plt.ylabel('Count')
plt.legend(['Accordeon', 'Dombyra', 'Kobyz'])
plt.show()

# %%
def draw_color_hist(y):
    plt.figure(figsize=(15,10))
    if y != 'all':
        plt.hist(image_data[image_data['y']==y]['total_intense'], bins = 256, color = 'grey', alpha=0.5)
        plt.hist(image_data[image_data['y']==y]['red_intense'], bins = 256, color = colors[0], alpha = 0.5)
        plt.hist(image_data[image_data['y']==y]['green_intense'], bins = 256, color = colors[2], alpha = 0.5)
        plt.hist(image_data[image_data['y']==y]['blue_intense'], bins = 256, color = colors[5], alpha = 0.5)
    else:
        plt.hist(image_data['total_intense'], bins = 256, color = 'grey', )
        plt.hist(image_data['red_intense'], bins = 256, color = colors[0], alpha = 0.5)
        plt.hist(image_data['green_intense'], bins = 256, color = colors[2], alpha = 0.5)
        plt.hist(image_data['blue_intense'], bins = 256, color = colors[5], alpha = 0.5)
    plt.title(f'Color histogram {y}')
    plt.xlabel('Intensity Value')
    plt.ylabel('Count')
    plt.legend(['Total', 'Red_Channel', 'Green_Channel', 'Blue_Channel'])
    plt.show()

# %%
draw_color_hist('all')

# %%
draw_color_hist('accordeon')

# %%
draw_color_hist('dombyra')

# %%
draw_color_hist('kobyz')

# %% [markdown]
# # Model preporation

# %% [markdown]
# ## Train, test splitting

# %%
batch_size = 4
image_size = 224

# %% [markdown]
# ### 80/20

# %%
datagen_80_20 = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True, validation_split=0.2)


df_train_80_20 = datagen_80_20.flow_from_directory(
        "data/",
        target_size=(image_size, image_size),
        batch_size=batch_size,
        class_mode='categorical', subset='training')


df_test_80_20 = datagen_80_20.flow_from_directory(
        "data/",
        target_size=(image_size, image_size),
        batch_size=batch_size,
        class_mode='categorical', subset='validation')
# Out:
# Found 495 images belonging to 3 classes.
# Found 123 images belonging to 3 classes.

# %% [markdown]
# ### 70/30

# %%
datagen_70_30 = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True, validation_split=0.3)


df_train_70_30 = datagen_70_30.flow_from_directory(
        "data/",
        target_size=(image_size, image_size),
        batch_size=batch_size,
        class_mode='categorical', subset='training')


df_test_70_30 = datagen_70_30.flow_from_directory(
        "data/",
        target_size=(image_size, image_size),
        batch_size=batch_size,
        class_mode='categorical', subset='validation')
# Out:
# Found 434 images belonging to 3 classes.
# Found 184 images belonging to 3 classes.

# %% [markdown]
# # My model

# %%
def myModel():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(16, (7, 7), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(3, activation="softmax")])
    
    model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=tf.metrics.categorical_accuracy)
    
    return model

# %% [markdown]
# ## Train model on 80/20 dataset

# %%
my_model_80_20 = myModel()
with tf.device("GPU"):
    history_80_20 = my_model_80_20.fit(df_train_80_20, validation_data=df_test_80_20, epochs=10)
# Out:
# Epoch 1/10
# 62/62 [==============================] - 13s 205ms/step - loss: 8.4080 - categorical_accuracy: 0.4559 - val_loss: 0.8390 - val_categorical_accuracy: 0.4959
# Epoch 2/10
# 62/62 [==============================] - 12s 198ms/step - loss: 0.9094 - categorical_accuracy: 0.5926 - val_loss: 0.7087 - val_categorical_accuracy: 0.6992
# Epoch 3/10
# 62/62 [==============================] - 12s 195ms/step - loss: 0.7590 - categorical_accuracy: 0.7009 - val_loss: 0.8043 - val_categorical_accuracy: 0.6748
# Epoch 4/10
# 62/62 [==============================] - 12s 198ms/step - loss: 0.7005 - categorical_accuracy: 0.7547 - val_loss: 0.4722 - val_categorical_accuracy: 0.8699
# Epoch 5/10
# 62/62 [==============================] - 12s 195ms/step - loss: 0.6938 - categorical_accuracy: 0.7708 - val_loss: 0.5242 - val_categorical_accuracy: 0.8211
# Epoch 6/10
# ...

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(10), history_80_20.history['loss'], label='train loss')
plt.plot(np.arange(10), history_80_20.history['val_loss'], label='test loss')

plt.legend()
plt.title(f'My model 80/20 loss on train and test')
plt.xlabel('Epoches')
plt.ylabel('Loss');

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(10), history_80_20.history['categorical_accuracy'], label='train accuracy')
plt.plot(np.arange(10), history_80_20.history['val_categorical_accuracy'], label='test accuracy')

plt.legend()
plt.title(f'My model 80/20 accuracy on train and test')
plt.xlabel('Epoches')
plt.ylabel('Accuracy');

# %% [markdown]
# ## Train model on 70/30 dataset

# %%
my_model_70_30 = myModel()
with tf.device("GPU"):
    history_70_30 = my_model_70_30.fit(df_train_70_30, validation_data=df_test_70_30, epochs=10)
# Out:
# Epoch 1/10
# 55/55 [==============================] - 13s 230ms/step - loss: 4.4330 - categorical_accuracy: 0.4761 - val_loss: 1.6927 - val_categorical_accuracy: 0.4511
# Epoch 2/10
# 55/55 [==============================] - 12s 219ms/step - loss: 1.0877 - categorical_accuracy: 0.5403 - val_loss: 0.5737 - val_categorical_accuracy: 0.7500
# Epoch 3/10
# 55/55 [==============================] - 13s 228ms/step - loss: 0.8334 - categorical_accuracy: 0.6949 - val_loss: 0.8823 - val_categorical_accuracy: 0.6467
# Epoch 4/10
# 55/55 [==============================] - 13s 228ms/step - loss: 0.7836 - categorical_accuracy: 0.6885 - val_loss: 0.5798 - val_categorical_accuracy: 0.7826
# Epoch 5/10
# 55/55 [==============================] - 13s 240ms/step - loss: 0.6263 - categorical_accuracy: 0.7187 - val_loss: 0.5437 - val_categorical_accuracy: 0.7826
# Epoch 6/10
# ...

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(10), history_70_30.history['loss'], label='train loss')
plt.plot(np.arange(10), history_70_30.history['val_loss'], label='test loss')

plt.legend()
plt.title(f'My model 70/30 loss on train and test')
plt.xlabel('Epoches')
plt.ylabel('Loss');

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(10), history_70_30.history['categorical_accuracy'], label='train accuracy')
plt.plot(np.arange(10), history_70_30.history['val_categorical_accuracy'], label='test accuracy')

plt.legend()
plt.title(f'My model 70/30 accuracy on train and test')
plt.xlabel('Epoches')
plt.ylabel('Accuracy');

# %% [markdown]
# # model VGG16

# %%
def vgg16Model():
    model = tf.keras.models.Sequential([
        tf.keras.applications.VGG16(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(3, activation="softmax")])
    
    model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=tf.metrics.categorical_accuracy)
    
    return model

# %% [markdown]
# ## Train model on 80/20 dataset

# %%
vgg16_model_80_20 = vgg16Model()
with tf.device("GPU"):
    history_80_20 = vgg16_model_80_20.fit(df_train_80_20, validation_data=df_test_80_20, epochs=5)

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(5), history_80_20.history['loss'], label='train loss')
plt.plot(np.arange(5), history_80_20.history['val_loss'], label='test loss')

plt.legend()
plt.title(f'My model 80/20 loss on train and test')
plt.xlabel('Epoches')
plt.ylabel('Loss');

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(5), history_80_20.history['categorical_accuracy'], label='train accuracy')
plt.plot(np.arange(5), history_80_20.history['val_categorical_accuracy'], label='test accuracy')

plt.legend()
plt.title(f'My model 80/20 accuracy on train and test')
plt.xlabel('Epoches')
plt.ylabel('Accuracy');

# %% [markdown]
# ## Train model on 70/30 dataset

# %%
vgg16_model_70_30 = mobileNetV2Model()
with tf.device("GPU"):
    history_70_30 = vgg16_model_70_30.fit(df_train_70_30, validation_data=df_test_70_30, epochs=5)

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(5), history_70_30.history['loss'], label='train loss')
plt.plot(np.arange(5), history_70_30.history['val_loss'], label='test loss')

plt.legend()
plt.title(f'My model 70/30 loss on train and test')
plt.xlabel('Epoches')
plt.ylabel('Loss');

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(5), history_70_30.history['categorical_accuracy'], label='train accuracy')
plt.plot(np.arange(5), history_70_30.history['val_categorical_accuracy'], label='test accuracy')

plt.legend()
plt.title(f'My model 70/30 accuracy on train and test')
plt.xlabel('Epoches')
plt.ylabel('Accuracy');

# %% [markdown]
# # Results

# %%
def metrics(y_test, y_pred):
    print('f1_score =', f1_score(y_test, y_pred, average='weighted'))
    print('recall =', recall_score(y_test, y_pred, average='weighted'))
    print('precision =', precision_score(y_test, y_pred,average='weighted'))
    conf_mat = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(15, 15))
    sns.heatmap(conf_mat/len(y_test) * 100, annot=True)

# %%
pred_80_20 = custom_model_80_20.predict(df_test_80_20)
pred_70_30 = custom_model_70_30.predict(df_test_70_30)

pred_vgg16_80_20 = vgg16_model_80_20.predict(df_test_80_20)
pred_vgg16_70_30 = vgg16_model_70_30.predict(df_test_70_30)

# %%
pred_80_20 = np.argmax(pred_80_20, axis=1)
pred_70_30 = np.argmax(pred_70_30, axis=1)

pred_vgg16_80_20 = np.argmax(pred_vgg16_80_20, axis=1)
pred_vgg16_70_30 = np.argmax(pred_vgg16_70_30, axis=1)

df_test_y_70_30 = [df_test_70_30.classes[i - 1] for i in df_test_70_30.index_array]
df_test_y_80_20 = [df_test_80_20.classes[i - 1] for i in df_test_80_20.index_array]

# %%
metrics(df_test_y_80_20, pred_80_20)

# %%
metrics(df_test_y_70_30, pred_vgg16_70_30)

# %%
metrics(df_test_80_20.classes, pred_vgg16_80_20)

# %%
metrics(df_test_70_30.classes, pred_vgg16_70_30)

# %%
dir(df_test_70_30)

# %%
[df_test_70_30.classes[i - 1] for i in df_test_70_30.index_generator]

# %%
df_test_70_30.allowed_class_modes
